# %% [markdown]
# ### Test run for the unique mutation caller app
# ---

# %% [markdown]
# #### Compile

# %%
# %%bash
# gcc -c -O3 unique_mutation_lib.c fisher.c  -W -Wall
# gcc -O3 -o unique_mutation_app unique_mutation_app.c unique_mutation_lib.o  fisher.o -lm -W -Wall

# %% [markdown]
# #### Sample run

# %%
# %%bash
# min_sample_freq=0.2
# min_other_freq=0.8
# cov_limit=5
# base_quality_limit=30
# snv_proximal_gap_filter_distance=10
# indel_proximal_gap_filter_distance=20
#
# time /home/ribli/tools/samtools-1.2/samtools mpileup  -B \
# -f /home/ribli/input/index/gallus/Gallus_gallus.Galgal4.74.dna.toplevel.fa \
# -r 1:0-1,000,000  \
# /nagyvinyok/adat83/sotejedlik/ribli/dt40/bam_links_2/DS001_RMdup_picard_realign.bam \
# /nagyvinyok/adat83/sotejedlik/ribli/dt40/bam_links_2/DS003_RMdup_picard_realign.bam \
# /nagyvinyok/adat83/sotejedlik/ribli/dt40/bam_links_2/DS004_RMdup_picard_realign.bam \
# /nagyvinyok/adat83/sotejedlik/ribli/dt40/bam_links_2/DS006_RMdup_picard_realign.bam \
# /nagyvinyok/adat83/sotejedlik/ribli/dt40/bam_links_2/DS041_RMdup_picard_realign.bam \
# /nagyvinyok/adat83/sotejedlik/ribli/dt40/bam_links_2/DS042_RMdup_picard_realign.bam \
# /nagyvinyok/adat83/sotejedlik/ribli/dt40/bam_links_2/DS043_RMdup_picard_realign.bam \
# /nagyvinyok/adat83/sotejedlik/ribli/dt40/bam_links_2/DS044_RMdup_picard_realign.bam \
# /nagyvinyok/adat83/sotejedlik/ribli/dt40/bam_links_2/DS045_RMdup_picard_realign.bam \
# /nagyvinyok/adat83/sotejedlik/ribli/dt40/bam_links_2/DS046_RMdup_picard_realign.bam \
# /nagyvinyok/adat83/sotejedlik/ribli/dt40/bam_links_2/DS047_RMdup_picard_realign.bam \
# /nagyvinyok/adat83/sotejedlik/ribli/dt40/bam_links_2/DS048_RMdup_picard_realign.bam \
# /nagyvinyok/adat83/sotejedlik/ribli/dt40/bam_links_2/DS049_RMdup_picard_realign.bam \
# /nagyvinyok/adat83/sotejedlik/ribli/dt40/bam_links_2/DS050_RMdup_picard_realign.bam \
# /nagyvinyok/adat83/sotejedlik/ribli/dt40/bam_links_2/DS097_RMdup_picard_realign.bam \
# | \
# ./unique_mutation_app $min_sample_freq $min_other_freq $cov_limit $base_quality_limit \
# $snv_proximal_gap_filter_distance $indel_proximal_gap_filter_distance
# Out:
# #sample	chr	pos	type	fisher_p_value	ref	mut
# 8	1	118	SNV	2.964427e-02	T	C
# 8	1	287	SNV	5.378040e-01	C	T
# 8	1	294	SNV	5.818856e-01	T	G
# 8	1	303	SNV	6.125429e-01	G	A
# 12	1	894	SNV	8.491778e-01	T	C
# 12	1	1399	SNV	2.368421e-01	C	A
# 6	1	1565	SNV	7.910217e-01	T	A
# 6	1	1582	SNV	6.000000e-01	C	T
# 8	1	1588	SNV	2.272727e-01	T	A
# 5	1	1782	SNV	1.666667e-01	G	T
# 12	1	2396	SNV	1.562500e-01	C	A
# 11	1	3019	SNV	4.400527e-01	T	C
# 5	1	3296	SNV	3.181818e-01	G	A
# 10	1	3618	SNV	5.000000e-01	C	T
# 13	1	3688	SNV	7.871345e-01	C	T
# 6	1	3703	SNV	4.433465e-01	A	G
# 9	1	3710	SNV	4.467256e-01	G	T
# 6	1	3716	SNV	8.269682e-01	G	T
# 11	1	3915	SNV	7.619048e-01	A	G
# 11	1	3919	SNV	2.941176e-01	C	G
# 6	1	4060	SNV	3.823529e-01	T	G
# 8	1	4062	SNV	4.433465e-01	C	T
# 11	1	4093	SNV	5.416667e-01	G	T
# 11	1	4102	SNV	4.400527e-01	C	T
# 3	1	4229	SNV	8.360868e-01	G	T
# 3	1	4235	SNV	8.292856e-01	C	T
# 12	1	4248	DEL	6.055433e-01	g	-
# 6	1	4860	SNV	2.380952e-01	G	T
# 10	1	5006	SNV	4.727818e-01	G	A
# ...
